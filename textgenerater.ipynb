# %% [markdown]
# JACK &nbsp;IGANGA &nbsp; IN13/00067/21<BR>
# FELIX &nbsp;SHIKUKU &nbsp;IN14/00059/21<BR>
# WILSON &nbsp;OCHIENG &nbsp;
# IN1400033/21

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Larger Text Dataset
text = """This is Jtech, a software training institute.
          It provides coding tutorials, interview preparation,
          and courses on programming languages like Python, Java,
          and C++. Jtech is a popular platform for developers."""

# Character Mapping
chars = sorted(list(set(text)))
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

# Sequence Preparation
seq_length = 5  # Increased sequence length for better predictions
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

X = np.array(sequences)
y = np.array(labels)

# One-Hot Encoding
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# Model Definition
model = Sequential([
    SimpleRNN(100, input_shape=(seq_length, len(chars)), activation='relu'),
    Dense(len(chars), activation='softmax')
])

# Compile & Train
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_one_hot, y_one_hot, epochs=100)

# **Text Generation Based on User Input**
while True:
    start_seq = input("Enter a starting sequence (at least 5 chars): ")

    if len(start_seq) < seq_length:
        print(f"Please enter at least {seq_length} characters.")
        continue

    generated_text = start_seq

    for i in range(100):  # Generate 100 characters
        x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
        x_one_hot = tf.one_hot(x, len(chars))
        prediction = model.predict(x_one_hot)
        next_index = np.argmax(prediction)
        next_char = index_to_char[next_index]
        generated_text += next_char

    print("\nGenerated Text:")
    print(generated_text)
    print("\n----------------------\n")
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.0574 - loss: 3.4182
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2230 - loss: 3.2856
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2481 - loss: 3.0943
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2460 - loss: 2.8620
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2247 - loss: 2.8104
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2601 - loss: 2.6375
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2571 - loss: 2.5699
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2485 - loss: 2.5276
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2608 - loss: 2.4536
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3057 - loss: 2.3658
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2660 - loss: 2.4079
# Epoch 12/100
# ...
